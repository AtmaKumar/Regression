# %% [markdown]
# # Lets create a simple data for Doing Regression through Scratch using Gradient Descent

# %% [raw]
# Let's define x

# %%
x=[2,4,5,7,8,9,10,11,13,14,15,16,19,20,21,22,24,25]
len(x)
# Out:
# 18

# %% [raw]
# Let's define y

# %%
y=[5,9,13,16,18,20,20,21,23,26,29,31,33,39,40,43,46,49]
len(y)
# Out:
# 18

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,color="red")
plt.title("Plot")
plt.xlabel("Input")
plt.ylabel("Output")
# Out:
# Text(0, 0.5, 'Output')

# %% [raw]
# From the above plot you can say this is a simple Linear eqn.So let's define Yp=w0+w1*x.

# %% [raw]
# Take wo and w1 random

# %%
w0=.1
w1=.2
import numpy as np
x=np.array(x)
y=np.array(y)

# %%
yp=w0+w1*x

# %%
yp
# Out:
# array([0.5, 0.9, 1.1, 1.5, 1.7, 1.9, 2.1, 2.3, 2.7, 2.9, 3.1, 3.3, 3.9,
#        4.1, 4.3, 4.5, 4.9, 5.1])

# %%
plt.plot(x,y,color="red")
plt.plot(x,yp,color="green")
plt.title("Plot")
plt.xlabel("Input")
plt.ylabel("Output")
# Out:
# Text(0, 0.5, 'Output')

# %% [raw]
# Let's Calculate The Loss

# %%
Loss=(yp-y)**2

# %%
Loss
# Out:
# array([  20.25,   65.61,  141.61,  210.25,  265.69,  327.61,  320.41,
#         349.69,  412.09,  533.61,  670.81,  767.29,  846.81, 1218.01,
#        1274.49, 1482.25, 1689.21, 1927.21])

# %%
sum(Loss)
# Out:
# 12522.900000000001

# %%
plt.plot(yp-y,Loss)
plt.title("Loss")
plt.xlabel("yp-y")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [raw]
# Lets do the Gradient and Minimize the Loss

# %%
k=0
plt.plot(x,y,color="red")

w0=.1
w1=.2
n=len(x)
lr=.00001
while(k<500):
    yp=w0+w1*x
    Loss1=(yp-y)**2
    Loss=sum((yp-y)**2)*(1/n)
    dw0=2*sum(yp-y)*(1/n)
    dw1=2*(sum(yp-y))*x*(1/n)
    w0=w0-lr*dw0
    w1=w1-lr*dw1
    k=k+1
    if(k%20==0):
        plt.plot(x,yp,color="green")

# %%
plt.plot(x,y,color="red")
plt.plot(x,yp,color="green")
plt.title("Plot")
plt.xlabel("Input")
plt.ylabel("Output")
# Out:
# Text(0, 0.5, 'Output')

# %% [raw]
# Let's check the Final Loss it is MSE

# %%
Loss
# Out:
# 61.60783034919402

# %% [raw]
# Let's find RMSE

# %%
RMSE=np.sqrt(Loss)

# %%
RMSE
# Out:
# 7.849065571722154
